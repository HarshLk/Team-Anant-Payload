# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %%
pic = cv2.imread(r'C:\Users\harsh\OneDrive\Desktop\clocktower.jpg', cv2.IMREAD_COLOR)

# %%
imagen=np.asarray(Image.fromarray(pic).reduce(1))
imagene = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(imagene)
